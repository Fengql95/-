# %% [markdown]
# #  箱线图

# %%
# 导入包
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

# %%
# 数据准备
data = np.random.normal(size=(10,4))
labels = ['A', 'B', 'C','D']

# %%
data
# Out:
# array([[-0.10606275,  0.51004723, -1.77831631, -0.57452092],
#        [-0.24556912,  0.81616595, -0.74344997, -1.60276305],
#        [-0.50548623,  0.19622422,  1.07140088,  1.89900548],
#        [-0.48350207,  0.26845006, -0.47528789, -0.15913121],
#        [-1.97877805, -0.52249214, -0.25208524, -0.99366063],
#        [-0.76653602,  0.21202181,  0.61890978,  0.79283007],
#        [ 0.03098109, -0.85729341,  0.78947255, -0.41427802],
#        [ 1.96479808,  1.01977267, -0.97089948, -0.71731857],
#        [ 0.03987953,  1.4393002 , -0.36824161,  0.39536848],
#        [ 0.12061805, -0.76964684,  0.39385335,  0.20749605]])

# %%
# matplotlib
plt.boxplot(data, labels=labels)
plt.show()

# %%
# seaborn 
df = pd.DataFrame(data, columns=labels)
sns.boxplot(data = df)
plt.show()
